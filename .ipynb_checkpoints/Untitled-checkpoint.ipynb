# %%
import pandas as pd 
result =  pd.Series(["japan","usa","nepal"])
print(result)
# Out:
# 0    japan
# 1      usa
# 2    nepal
# dtype: str

# %%
number_series = pd.Series([10, 20, 30 ], index=["ek","dui","tin"])
print(number_series)
# Out:
# ek     10
# dui    20
# tin    30
# dtype: int64

# %%
 datas = pd.read_csv("Datasets/student_data.csv")
 print(datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
netflix_data= pd.read_csv("./Datasets/netflix_titles.csv")
print(netflix_data.head(2)) //gives first 2 rows of the data 
print(netflix_data.tail(2)) //gives laast 2 rows of the data 
print(nd.sample(3)) // gives 3 random data
print(netflix_data.shape) //how many rows and column 
print(netflix_data.columns) // datasets ma vako column return garcha
print(netflix_data.dtypes) // datasets ma vako column ko datatype return garcha
print(netflix_data.info()) // shape,column, dtypes all in one master method
print(netflix_data.describe()) //numerical description, numerical columns xa teslai describe garcha
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
student_Dp = pd.read_json("./Datasets/students_data.json")
print(student_Dp)
print(student_Dp.head(5))
print(student_Dp.tail(3))
print(student_Dp.shape)
print(student_Dp.columns)
print(student_Dp.dtypes)
print(student_Dp.info())
print(student_Dp.describe())
print(student_Dp['name'])
print(student_Dp[['name','age']])
print(student_Dp.head(1))
print(student_Dp.tail(1))
print(student_Dp[student_Dp['id']==5])
print(student_Dp[student_Dp['location']=='Kathmandu'])
print(student_Dp[student_Dp['age']>21])
print(student_Dp[student_Dp['gender']=='Female'])
print(student_Dp[student_Dp['attendance']>90])
print(student_Dp[student_Dp['marks']>85])
print(student_Dp[student_Dp['courses_enrolled'].apply(lambda x: 'Python' in x)])
# Out:
#       id             name  age  gender       phone  \
# 2      3     Nabin Pandey   26    Male  9834006426
# 3      4     Roshan Regmi   27  Female  9811229824
# 17    18     Sabina Dahal   19  Female  9888478039
# 19    20  Sabina Shrestha   20  Female  9851899869
# 22    23  Nabin Bhattarai   24    Male  9833072767
# ..   ...              ...  ...     ...         ...
# 468  469        Roshan KC   24  Female  9873162845
# 470  471     Asmita Joshi   26    Male  9806889815
# 473  474    Ritika Pandey   27    Male  9840557150
# 484  485   Alina Bhandari   26    Male  9801096657
# 490  491         Pooja KC   28  Female  9867136985
#
#                            email   location   district province  \
# 2        nabin.pandey3@gmail.com  Kathmandu  Kathmandu  Bagmati
# 3        roshan.regmi4@gmail.com     Dharan    Sunsari    Koshi
# 17      sabina.dahal18@gmail.com    Itahari    Sunsari    Koshi
# 19   sabina.shrestha20@gmail.com  Nepalgunj      Banke  Lumbini
# ...

# %%
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9           10     Keyboard  Electronics   2500                5     4.4
# 10          11       Bottle         Home    800                0     5.5
# 11          12        Chair    Furniture  -2500               10     4.0
#
# ...

# %%
# Out:
# 0     75000.0
# 1     16730.0
# 2      3500.0
# 3      1500.0
# 4      5500.0
# 5      4200.0
# 6     75000.0
# 7     16730.0
# 8      1800.0
# 9      2500.0
# 10      800.0
# 11    -2500.0
# Name: price, dtype: float64

# %%
# Out:
#     product_id product_name     category    price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000.0               10     4.8
# 1            2        Phone  Electronics      NaN               15     4.6
# 2            3        Shoes      Fashion   3500.0               5%     4.2
# 3            4      T-Shirt      Fashion   1500.0               20     NaN
# 4            5        Watch  Accessories   5500.0               10     4.5
# 5            6   Headphones  Electronics   4200.0              NaN     4.1
# 6            7       Laptop  Electronics  75000.0               10     4.8
# 7            8          Bag      Fashion      NaN               12     3.9
# 8            9        Mouse  Electronics   1800.0                5     4.3
# 9           10     Keyboard  Electronics   2500.0                5     4.4
# 10          11       Bottle         Home    800.0                0     5.5
# ...

# %%
# bdd.dropna() //deleteall the row having NaN
# bdd.duplicate() //to see the duplicate data
bdd["discount_percent"]=bdd["discount_percent"].str.replace("%" ," " , regex= False)
bdd
# Out:
#     product_id product_name     category    price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000.0               10     4.8
# 1            2        Phone  Electronics      NaN               15     4.6
# 2            3        Shoes      Fashion   3500.0               5      4.2
# 3            4      T-Shirt      Fashion   1500.0               20     NaN
# 4            5        Watch  Accessories   5500.0               10     4.5
# 5            6   Headphones  Electronics   4200.0              NaN     4.1
# 6            7       Laptop  Electronics  75000.0               10     4.8
# 7            8          Bag      Fashion      NaN               12     3.9
# 8            9        Mouse  Electronics   1800.0                5     4.3
# 9           10     Keyboard  Electronics   2500.0                5     4.4
# 10          11       Bottle         Home    800.0                0     5.5
# ...
